# %%
# Housekeeping
#===============================================================================
import mne
import numpy as np
import os, re, sys
import scipy 
import cde_seeg_functions as cs
import matplotlib.pyplot as plt
from importlib import reload
import powerlaw as pl
reload(cs)

# Define folder locations
#-------------------------------------------------------------------------------
F = {}
F['base']    = '/Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy'
F['save']    = '/Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy Data'
F['scripts'] = F['base'] +os.sep+ '07 - SEEG'
F['seeg']    = '/Volumes/KANDINSKY/1808 Intracranial Seizure Data'
Sub          = cs.subspec(F)

# %%
# Manual definitions of various parameters
#===============================================================================
# Preprocessing
#-------------------------------------------------------------------------------
PP = {}
PP['Fbp']            = (80,250)      # Bandpass filter frequency band

# Binarisation
#-------------------------------------------------------------------------------
BN = {}
BN['separation_win'] = 0
BN['peak_height']    = 3

# Avalanche size estimation
#-------------------------------------------------------------------------------
AS = {}
AS['dt']             = 3  # delta t for detection of concurrent events (in samples)

# %%
importlib.reload(cs)

for s in range(len(Sub)):

    # Binarise and calculate cascade statistics 
    #-------------------------------------------------------------------------------
    Sub[s] = cs.binarise(Sub[s], PP, BN)
# Out:
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 95999  =      0.000 ...    93.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...    75.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ArRy/ArRy_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 110079  =      0.000 ...   107.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 263167  =      0.000 ...   256.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 280063  =      0.000 ...   273.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BeNe/BeNe_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 95231  =      0.000 ...    92.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33279  =      0.000 ...    32.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 136191  =      0.000 ...   132.999 secs...
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:38: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   bl     = mne.io.read_raw_edf(sub['Base'][0])
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:38: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl     = mne.io.read_raw_edf(sub['Base'][0])
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34303  =      0.000 ...    33.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 102399  =      0.000 ...    99.999 secs...
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34303  =      0.000 ...    33.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/BlMo/BlMo_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 112127  =      0.000 ...   109.499 secs...
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: 21 channel names are too long, have been truncated to 15 characters:
# ['EEG M1PIns10-Ref', 'EEG MFGACi10-Ref', 'EEG MFGACin9-Ref', 'EEG MFGACin8-Ref', 'EEG MFGACin7-Ref', 'EEG MFGACin6-Ref', 'EEG MFGACin5-Ref', 'EEG MFGACin4-Ref', 'EEG MFGACin3-Ref', 'EEG MFGACin2-Ref', 'EEG SFGAIn10-Ref', 'EEG SFGAIns9-Ref', 'EEG SFGAIns8-Ref', 'EEG SFGAIns7-Ref', 'EEG SFGAIns6-Ref', 'EEG SFGAIns5-Ref', 'EEG SFGAIns4-Ref', 'EEG SFGAIns3-Ref', 'EEG SFGAIns2-Ref', 'EEG AngPCin3-Ref', 'EEG AngPCin2-Ref']
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33023  =      0.000 ...    32.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 268031  =      0.000 ...   261.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33023  =      0.000 ...    32.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 70015  =      0.000 ...    68.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChCr/ChCr_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 66047  =      0.000 ...    64.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 31999  =      0.000 ...    31.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 47999  =      0.000 ...    46.874 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 56063  =      0.000 ...    54.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ChSe/ChSe_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 105087  =      0.000 ...   102.624 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33023  =      0.000 ...    32.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:38: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl     = mne.io.read_raw_edf(sub['Base'][0])
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 83199  =      0.000 ...    81.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 100095  =      0.000 ...    97.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 44031  =      0.000 ...    42.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ErMcSt/ErMcSt_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 89087  =      0.000 ...    86.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 2 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/EsCh/EsCh_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/EsCh/EsCh_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33023  =      0.000 ...    32.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:38: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl     = mne.io.read_raw_edf(sub['Base'][0])
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/EsCh/EsCh_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 84223  =      0.000 ...    82.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/EsCh/EsCh_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/EsCh/EsCh_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 37119  =      0.000 ...    36.249 secs...
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# ...
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/TiPe/TiPe_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 27135  =      0.000 ...    52.998 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 6.00 Hz (-6 dB cutoff frequency: 253.00 Hz)
# - Filter length: 283 samples (0.553 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/TiPe/TiPe_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 18431  =      0.000 ...    35.998 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 6.00 Hz (-6 dB cutoff frequency: 253.00 Hz)
# - Filter length: 283 samples (0.553 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/TiPe/TiPe_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33279  =      0.000 ...    64.998 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 6.00 Hz (-6 dB cutoff frequency: 253.00 Hz)
# - Filter length: 283 samples (0.553 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33279  =      0.000 ...    32.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 100351  =      0.000 ...    97.999 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33279  =      0.000 ...    32.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 109055  =      0.000 ...   106.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33279  =      0.000 ...    32.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/UzRa/UzRa_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 112127  =      0.000 ...   109.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Sz1_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:38: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl     = mne.io.read_raw_edf(sub['Base'][0])
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Seizure1.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55039  =      0.000 ...    53.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Sz2_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Seizure2.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 73087  =      0.000 ...    71.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Sz3_Baseline.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 34047  =      0.000 ...    33.249 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:49: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   bl = mne.io.read_raw_edf(sub['Base'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Extracting EDF parameters from /Volumes/KANDINSKY/1808 Intracranial Seizure Data/ZaSa/ZaSa_Seizure3.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54015  =      0.000 ...    52.749 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 169 samples (0.165 sec)
# /Users/roschkoenig/Dropbox/Research/1812 Critical Dynamics Epilepsy/07 - SEEG/cde_seeg_functions.py:53: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   sz = mne.io.read_raw_edf(sub['Seiz'][k], preload=True)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
importlib.reload(cs)
for s in range(len(Sub)):
    bl = Sub[s]['bin_base']
    sz = Sub[s]['bin_seiz']

    f, (ax1,ax2) = plt.subplots(1,2,sharey=True, sharex=True, figsize=(20,10))
    ax1.hist(np.log(cs.avcount(bl, AS)), log=True, bins=50)
    ax2.hist(np.log(cs.avcount(sz, AS)), log=True, bins=50)
    f.show()
# Out:
# /Users/roschkoenig/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':
# /Users/roschkoenig/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
temp = np.zeros((len(Sub),2))
f,ax = plt.subplots(5,6, figsize=(20,20), sharex = True)

for s in range(len(Sub)):
    bl = Sub[s]['bin_base']
    sz = Sub[s]['bin_seiz']
    i  = (np.floor(s/6).astype('int'), np.mod(s,6)-1)
    
    avc        = cs.avcount(bl, AS)
    results    = pl.Fit(avc)
    R_bl,p_bl  = results.distribution_compare('power_law', 'lognormal_positive')
    al_bl      = results.alpha
    cs.plot_ccdf(avc, color=1, No_bins=50,ax=ax[i])
    
    avc        = cs.avcount(sz, AS)
    results    = pl.Fit(avc)
    R_sz,p_sz  = results.distribution_compare('power_law', 'lognormal_positive')
    al_sz      = results.alpha
    cs.plot_ccdf(avc, color=0, No_bins=50,ax=ax[i])

    Sub[s].update({'base_llh': (R_bl, p_bl), 'seiz_llh': (R_sz, p_sz), 'base_alpha':al_bl, 'seiz_alpha':al_sz})
    temp[s,:] = (al_bl, al_sz)
    
#    print('This is a power law', end =' ') if R >= 0 else print('This is rubbish', end = ' '),
#    print(', I''m sure') if p<0.05 else print(', maybe?')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-e070dadc947c> in <module>
# ----> 1 temp = np.zeros(len(Sub),2)
#       2 f,ax = plt.subplots(5,6, figsize=(20,20), sharex = True)
#       3
#       4 for s in range(len(Sub)):
#       5     bl = Sub[s]['bin_base']
#
# TypeError: data type not understood

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])
